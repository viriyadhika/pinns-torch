# %%
import scipy.io
import numpy as np
from pyDOE import lhs

noise = 0.0

# Doman bounds
lb = np.array([-5.0, 0.0])
ub = np.array([5.0, np.pi/2])
N0 = 50
N_b = 50
N_f = 20000
layers = [2, 100, 100, 100, 100, 2]
    
data = scipy.io.loadmat('Data/NLS.mat')

t = data['tt'].flatten()[:,None]
x = data['x'].flatten()[:,None]
Exact = data['uu']
Exact_u = np.real(Exact)
Exact_v = np.imag(Exact)
Exact_h = np.sqrt(Exact_u**2 + Exact_v**2)

X, T = np.meshgrid(x,t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
u_star = Exact_u.T.flatten()[:,None]
v_star = Exact_v.T.flatten()[:,None]
h_star = Exact_h.T.flatten()[:,None]

###########################

idx_x = np.random.choice(x.shape[0], N0, replace=False)
x0 = x[idx_x,:]
u0 = Exact_u[idx_x,0:1]
v0 = Exact_v[idx_x,0:1]

idx_t = np.random.choice(t.shape[0], N_b, replace=False)
tb = t[idx_t,:]

X_f = lb + (ub-lb)*lhs(2, N_f)

# %% [markdown]
# x0 = random point in the samples
# u0 = real part of u at t = 0
# v0 = imaginary part of u at t = 0
# tb = random time in the samples
# X_f = 20,000 collocation point DOE in 2D grid in time and space
# lb = Array lower bound in x, t
# ub = Array upper bound in x, t

# %%
# u0_pred - Prediction at x0 and t0
self.u0_pred, self.v0_pred, _ , _ = self.net_uv(self.x0_tf, self.t0_tf)

# %%
X0 = np.concatenate((x0, 0*x0), 1) # (x0, 0)
X0[:5,0:1], X0[:5,1:2]
# Out:
# (array([[ 3.359375 ],
#         [-0.46875  ],
#         [-4.0625   ],
#         [-4.84375  ],
#         [ 2.6953125]]),
#  array([[ 0.],
#         [-0.],
#         [-0.],
#         [-0.],
#         [ 0.]]))
